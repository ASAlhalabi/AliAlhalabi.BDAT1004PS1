# %% [markdown]
# # Question-1: The data type are
#
# a) 5 is an integertype
#
#
# b)5.0 is a doubletype and running it in C# will give us 5 as the result
#
#
# c)5>1 is a relational operater which compares two value, Here the answer is true (Boolean expression)
#
#
# d)'5' is a char
#
#
# E)5 * 2 is arithmetic operater for multiplication, the answer should be 10. integer type.
#
#
# F)'5' * 2 Multiplying a char with an integer, the Char will be converted to ites character code, When running this into C# the Answer was 106.The result is an integer type
#
#
# G)'5'+'2' Adding two char , the char will be converted into its character code and when running this into C# the answer is 103. The result is an integer type.
#
#
# H) 5 / 2 is an arithmetic operater for division. The answer is 2 and the data type is integer.
#
#
# I)5 % 2 is an arithmetic operater for the remainder is an integertype.
#
#
# J){5, 2, 1} This is an array type
#
#
# K)5 == 3 is a relational operater , the answer is false when running this into c# (Boolean type)
#
#
# L)Pi (the number) is a double-precision floating type.

# %% [markdown]
# # Question-2-a:
# The count of letters in 'Supercalifragilisticexpialidocious'?
# Code
#
#
# using System;
#
# namespace Dataprogramming_HW1
#
# {
#     class Program
#
#     {
#         static void Main(string[] args)
#
#         {
#             // Define the String
#
#             string txt = "Supercalifragilisticexpialidocious";
#
#             // This line print the phrase "The length of the txt string is: ", the txt.length will return the count of the
# string
#
#             Console.WriteLine("The length of the txt string is: " + txt.Length);
#         }
#     }
# }
#
# ![title](Question2output.png)

# %% [markdown]
# # Question-2-b:
# Does 'Supercalifragilisticexpialidocious' contain 'ice' as a substring?
# Code
#
#
# using System;
#
# namespace Dataprogramming_HW1
#
# {
#     class Program
#
#     {
#         static void Main(string[] args)
#         {
#             //Defining my string
#
#             string mystring = "Supercalifragilisticexpialidocious";
#
#             // Boolean value if the the string contain the word "ice"
#
#             bool b = mystring.Contains("ice");
#
#             Console.WriteLine(b);
#
#         }
#     }
# }
# ![title](question2b.png)

# %% [markdown]
# # Question-2c:
# Which of the following words is the longest:
# Supercalifragilisticexpialidocious, Honorificabilitudinitatibus, or
# Bababadalgharaghtakamminarronnkonn?
# Code:
#
#
# using System;
#
# namespace Dataprogramming_HW1
# {
#     class Program
#
#     {
#         static void Main(string[] args)
#
#         {
#             // defining the three strings
#
#             String S1 = "Supercalifragilisticexpialidocious";
#
#             String S2 = "Honorificabilitudinitatibus";
#
#             String S3 = "Bababadalgharaghtakamminarronnkonn";
#
#             // get the length of each string and converting it to integer
#
#             int w1 = Convert.ToInt32("Supercalifragilisticexpialidocious".Length);
#
#             int w2 = Convert.ToInt32("Honorificabilitudinitatibus".Length);
#
#             int w3 = Convert.ToInt32("Bababadalgharaghtakamminarronnkonn".Length);
#
#             // if ladder compaers the if the each string has the lenght or not ( as discussed with the proff)
#
#              if (w1 == w2)
#
#                  Console.WriteLine("Both {0} & {1} has the same lenght with {2} & {3}",S1,S2,w1,w2);
#
#              else if (w1 == w3)
#
#                 Console.WriteLine("Both {0} & {1} has the same lenght with {2} & {3}", S1, S3, w1, w3);
#
#               else if (w2 == w3)
#
#                  Console.WriteLine("Both {0} & {1} has the same lenght with {2} & {3}", S3, S2, w3, w2);
#
#               else
#
#                 Console.WriteLine("They are not equal");
#
#         }
#     }
# }
# ![title](question2c.png)

# %% [markdown]
# # Question-2-D:
# Which composer comes first in the dictionary: 'Berlioz', 'Borodin', 'Brian',
# 'Bartok', 'Bellini', 'Buxtehude', 'Bernstein'. Which one comes last?
# code:
#
# # I have used the sorted list as I couldnt index it from the sorted dictionary
#
# using System;
#
# using System.Collections.Generic;
#
# namespace Dataprogramming_HW1
# {
#     class Program
#     {
#         static void Main(string[] args)
#         {
#
#             // First we defind the array string\
#
#             string[] names = { "Berlioz", "Borodin", "Brian", "Bartok", "Bellini", "Buxtehude", "Bernstein" };
#
#             // sort the array alphapatically
#
#             Array.Sort(names);
#
#             foreach (string alpha in names)
#
#             {
#                 // calling the first and the last name in the sorted array
#
#                 Console.WriteLine(names[0]);
#
#                 Console.WriteLine(names[names.Length-1]);
#
#                 break;
#
#             }
#         }
#     }
# }
# ![title](question2d.png)

# %% [markdown]
# # Question -3
# The area of the triangle is :
# Code
#
# using System;
#
# namespace Dataprogramming_HW1
# {
#     class Program
#     {
#         public static void Main(string[] args)
#         {
#             Console.WriteLine("Enter the length of the sides:");
#
#             int S1 = Convert.ToInt32(Console.ReadLine());
#
#             int S2 = Convert.ToInt32(Console.ReadLine());
#
#             int S3 = Convert.ToInt32(Console.ReadLine());
#
#             double s = (S1 + S2 + S3) / 2;
#
#             double A = Math.Sqrt(s * (s - S1) * (s - S2) * (s - S3));
#
#             Console.Write("Area of a Triangle = {0}", A);
#
#
#         }
#     }
# }
# ![title](question3.png)

# %% [markdown]
# # Question -4
# The odd and the even number are
# code:
#
# I have used (https://www.w3resource.com/csharp-exercises/array/csharp-array-exercise-10.php) to code this.
# using System;
#
# namespace Dataprogramming_HW1
#
# {
#     public class Exercise10
#
#     {
#         public static void Main()
#
#         {
#             int[] arr1 = new int[5];
#
#             int[] arr2 = new int[5];
#
#             int[] arr3 = new int[5];
#
#             int i;// will use this for the loop
#
#             int j = 0;
#             int m = 0;
#             int a;// this gonna be the number of elements
#                   // we ask the user to input the number of elements
#             Console.Write("Array dimension is 1 and the number of element=");
#             a = Convert.ToInt32(Console.ReadLine());
#
#             // we ask the user to input the number of the array by creating a loop for user input and we define the array to be i
#             Console.WriteLine("since you have defined the number of element in array to be {0}, now input the elements of the array ", a);
#             for (i = 0; i < a; i++)
#             {
#                 Console.Write("{0} : ", i);
#                 arr1[i] = Convert.ToInt32(Console.ReadLine());
#             }
#             // now testing the elements of the array to be even or odd by taking the remainder to equal zero or not and then we store them in different array.
#             for (i = 0; i < a; i++)
#             {
#                 if (arr1[i] % 2 == 0)
#                 {
#                     arr2[j] = arr1[i];
#                     j++;
#                 }
#                 else
#                 {
#                     arr3[m] = arr1[i];
#                     m++;
#                 }
#             }
#             // After getting which numbers are odd and even, we sort them based on that. The even elements are stored in array2 while odd elements are stored in array 3
#             Console.WriteLine("The Even elements are : ");
#             // This loop will return the even elements stored in array 2
#             for (i = 0; i < j; i++)
#             {
#                 Console.Write("{0} ", arr2[i]);
#             }
#             // This loop will return the odd elements stored in array 3
#             Console.WriteLine("The Odd elements are :");
#             for (i = 0; i < m; i++)
#             {
#                 Console.Write("{0} ", arr3[i]);
#             }
#
#         }
#     }
# }
# ![title](question4.png)

# %% [markdown]
# # Question -5-a:
#
# I have used https://www.geeksforgeeks.org/check-if-a-point-lies-on-or-inside-a-rectangle-set-2/ to help me code the problem.
#
# The function as below:
#
# using System;
#
# class GFG
#
# {
# 	// First we defind the function inside() to have the point and the upper right corner and lower left corner
#
# 	static bool inside (double x1, double y1, double x2,
# 						double y2, int x, int y)
#
# 	{
# 		// The function test if the point is greater than lower left corner and lower than upper left corner, if true then the point lies in the rectangle.
#
# 		if (x > x1 && x < x2 &&
# 			y > y1 && y < y2)
#
# 			return true;
#
# 			return false;
# 	}

# %% [markdown]
# # Question -5-b:
# Using the function from part a and writing an expression that test if a point lies in the rectangle:
#
# I have used https://www.geeksforgeeks.org/check-if-a-point-lies-on-or-inside-a-rectangle-set-2/ to help me code the problem.
#
# please note that:
#
# 1-The first time the rectangle lowerleft is (0.3,0.5) and upper right is (1.1,0.7)
#
# 2-The second time the rectangle lowerleft is (0.5,0.2) and upper right is (1.1,2)
#
# 3-The point is (1,1)
#
# Code as follow:
#
# using System;
#
# class GFG
# {
# 	// First we defind the function inside() to have the point and the upper right corner and lower left corner
# 	static bool inside (double x1, double y1, double x2,
# 						double y2, int x, int y)
# 	{
#
# 		// The function test if the point is greater than lower left corner and lower than upper left corner, if true then the point lies in the rectangle.
#
# 		if (x > x1 && x < x2 &&
# 			y > y1 && y < y2)
# 			return true;
# 			return false;
#
# 	}
# 	public static void Main()
#
# 	{
# 		// defining the variable of the function
#         // The point for the recatangle below is just for the first one, the second rectangle as in the output window below
# 		double x1 = 0.5;
# 		double y1 = 0.2;
# 		double x2 = 1.1;
# 		double y2 = 2;
# 		int x = 1;
# 		int y = 1;
#
# 		// calling the inside ()function and use to return of boolean expression is true or not
# 		if (inside(x1, y1, x2, y2, x, y))
# 			Console.WriteLine("	The point lies in the rectangle");
# 		else
# 			Console.WriteLine("The point doesnt belong to the rectangle");
# 	}
# }
#
# The first output as below
# ![title](question5a.png)
#
# The second output as below
# ![title](question5b.png)

# %%
# Question -6
#Converting a word into Latin word
#Code:
# We asked the user to enter the word
pig = input("Enter a word to be converted into Latin : ")
# Converting the word into lower case and splitting it
String = pig.lower().split()
# now we write a loop to check the first letter in
for word in String:
    if word[0] in 'aeiou': 
        #append is used to put the ""at the end of the word
        pig.append(word + 'way')
    else:
        pig.append(word[word.index(letter):] + word[:word.index(letter)] +'ay')
                # to break the loop
                
print(pig)
# I have used https://stackoverflow.com/questions/51508664/python-pig-latin-converter-words-that-start-with-consonants to code this.
# Out:
# Enter a word to be converted into Latin : Happy
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-ec3b500d2dc9> in <module>
#      12         pig.append(word + 'way')
#      13     else:
# ---> 14         pig.append(word[word.index(letter):] + word[:word.index(letter)] +'ay')
#      15                 # to break the loop
#      16
#
# AttributeError: 'str' object has no attribute 'append'

# %%
# Question -7
def bldcount():
    
    file = open('bloodtype1.txt', 'r')
    name = file.read()
    letters = name.split()
    A=letters.count('A')
    B=letters.count('B')
    AB=letters.count('AB')
    O=letters.count('O')
    OO= letters.count('OO')
    print (A)
    print  (B)
    print  (AB)
    print (O)
    print  (OO)

bldcount()
# Out:
# 15
# 1
# 13
# 15
# 0

# %%
#Question 8
def curconv(currency, amount):
    
    file = open ('currencies.txt','r') 
    content = file.read()
    words= content.split()
    for line in content:
        if words[0]==currency:
            factor=words[1]
            print(float(factor)*amount)
        break
curconv('AUD', 100)
# Out:
# 103.45157

# %% [markdown]
# # Question -9
# a)Trying to add incompatible variables, as in
# adding 6 + ‘a’
#
# #type error
#
# b)Referring to the 12th item of a list that has only 10
# items
#
# #index error
#
# C)Using a value that is out of range for a function’s
# input, such as calling math.sqrt(-1.0)
#
# #value error
#
# D)Using an undeclared variable, such as print(x)
# when x has not been defined
#
# #Name error
#
# E)Trying to open a file that does not exist, such as
# mistyping the file name or looking in the wrong
# directory.
#
# #Filenotfound error
